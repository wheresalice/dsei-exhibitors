# %%
import pandas as pd

# %%
df_2021 = pd.read_parquet("../parquet/dsei-2021")
df_2019 = pd.read_parquet("../parquet/dsei-2019")
df_2017 = pd.read_parquet("../parquet/dsei-2017")
df_2015 = pd.read_parquet("../parquet/dsei-2015")
df_2013 = pd.read_parquet("../parquet/dsei-2013")
df_2011 = pd.read_parquet("../parquet/dsei-2011")
df_2009 = pd.read_parquet("../parquet/dsei-2009")
df_2007 = pd.read_parquet("../parquet/dsei-2007")
df_2005 = pd.read_parquet("../parquet/dsei-2005")
df_2003 = pd.read_parquet("../parquet/dsei-2003")
df_2001 = pd.read_parquet("../parquet/dsei-2001")
df_1999 = pd.read_parquet("../parquet/dsei-1999")

# %%
df_2021
# Out:
#     address_iso2                                       address_text  \
# 0             GB  Chetwynd Bks\nChilwell\nNottingham\nNG9 5HA\nU...
# 1           None                                               None
# 2             US  River Front Services\n15049 Conference Center ...
# 3           None                                               None
# 4           None                                               None
# ..           ...                                                ...
# 800           GB  iTrinegy\nBusiness and Technology Centre\nBess...
# 801           GB  7 East Street\nTHAME\nOxfordshire\nOX9 3JS\nUn...
# 802         None                                               None
# 803           CH        Güterstrasse 20\nDäniken\n4658\nSwitzerland
# 804           DE         Werftstrasse 112-114\nKiel\n24143\nGermany
#
#            address_lat                              name country_iso2  \
# 0    52.91241090000000  170 (Infra Sp) Engineering Group         None
# 1                 None                  2 Excel Aviation           GB
# 2    38.88041000000000        21st Century Breaching Kit         None
# 3                 None                            360iSR           GB
# 4                 None                                3M           SE
# ..                 ...                               ...          ...
# 800  51.90178740000000                          iTrinegy         None
# 801  51.74521090000000                   kc4business Ltd         None
# 802               None                             maxon           GB
# 803  47.36121630000000                        saltech AG         None
# 804  54.31666560000000                      thyssenkrupp         None
#
#                                           exhibitorUrl            address_lon  \
# 0    https://www.dsei.co.uk/exhibitors/170-infra-sp...   -1.24352950000000000
# 1    https://www.dsei.co.uk/exhibitors/2excel-aviation                   None
# 2    https://www.dsei.co.uk/exhibitors/21st-century...  -77.45601700000000000
# 3             https://www.dsei.co.uk/exhibitors/360isr                   None
# 4                 https://www.dsei.co.uk/exhibitors/3m                   None
# ..                                                 ...                    ...
# 800         https://www.dsei.co.uk/exhibitors/itrinegy   -0.21586950000000000
# 801  https://www.dsei.co.uk/exhibitors/kc4business-ltd   -0.97315999999999990
# 802            https://www.dsei.co.uk/exhibitors/maxon                   None
# 803       https://www.dsei.co.uk/exhibitors/saltech-ag    7.97763210000000000
# 804  https://www.dsei.co.uk/exhibitors/thyssenkrupp...   10.15144700000000000
#
#        country_text
# 0              None
# 1    United Kingdom
# 2              None
# 3    United Kingdom
# 4            Sweden
# ..              ...
# 800            None
# 801            None
# 802  United Kingdom
# 803            None
# 804            None
#
# [805 rows x 8 columns]

# %%
df = pd.concat([df_2021, df_2019, df_2017, df_2015, df_2013, df_2011, df_2009, df_2007, df_2005, df_2003, df_2001, df_1999], axis=1)

# %%
df
# Out:
#      address_iso2                                       address_text  \
# 0              GB  Chetwynd Bks\nChilwell\nNottingham\nNG9 5HA\nU...
# 1            None                                               None
# 2              US  River Front Services\n15049 Conference Center ...
# 3            None                                               None
# 4            None                                               None
# ...           ...                                                ...
# 2187          NaN                                                NaN
# 2188          NaN                                                NaN
# 2189          NaN                                                NaN
# 2190          NaN                                                NaN
# 2191          NaN                                                NaN
#
#             address_lat                              name country_iso2  \
# 0     52.91241090000000  170 (Infra Sp) Engineering Group         None
# 1                  None                  2 Excel Aviation           GB
# 2     38.88041000000000        21st Century Breaching Kit         None
# 3                  None                            360iSR           GB
# 4                  None                                3M           SE
# ...                 ...                               ...          ...
# 2187                NaN                               NaN          NaN
# 2188                NaN                               NaN          NaN
# 2189                NaN                               NaN          NaN
# 2190                NaN                               NaN          NaN
# 2191                NaN                               NaN          NaN
#
#                                            exhibitorUrl  \
# 0     https://www.dsei.co.uk/exhibitors/170-infra-sp...
# 1     https://www.dsei.co.uk/exhibitors/2excel-aviation
# 2     https://www.dsei.co.uk/exhibitors/21st-century...
# 3              https://www.dsei.co.uk/exhibitors/360isr
# 4                  https://www.dsei.co.uk/exhibitors/3m
# ...                                                 ...
# 2187                                                NaN
# 2188                                                NaN
# 2189                                                NaN
# 2190                                                NaN
# 2191                                                NaN
#
#                 address_lon    country_text address_iso2  \
# 0      -1.24352950000000000            None         None
# 1                      None  United Kingdom           US
# 2     -77.45601700000000000            None           GB
# 3                      None  United Kingdom         None
# 4                      None          Sweden         None
# ...                     ...             ...          ...
# 2187                    NaN             NaN         None
# 2188                    NaN             NaN           DE
# 2189                    NaN             NaN         None
# 2190                    NaN             NaN         None
# 2191                    NaN             NaN           GB
#
#                             website  ...             name country_iso2  \
# 0                              None  ...  3e Technologies           US
# 1                https://14bis.aero  ...          3M (UK)           GB
# 2                http://army.mod.uk  ...   3-Way Networks           GB
# 3                              None  ...            911EP           US
# 4                              None  ...  AAI Corporation           US
# ...                             ...  ...              ...          ...
# 2187                           None  ...              NaN          NaN
# 2188  https://www.zoll.com/military  ...              NaN          NaN
# 2189                           None  ...              NaN          NaN
# 2190                           None  ...              NaN          NaN
# 2191           http://www.zuken.com  ...              NaN          NaN
#
#      country_text                                  name country_iso2  \
# 0             USA       AB Connectors (Northampton) Ltd           GB
# 1              UK              AB Precision (Poole) Ltd           GB
# 2              UK  ABRO (Army Base Repair Organisation)           GB
# 3             USA                      ACRA Control Ltd           IE
# 4             USA                  ADA Composite Armour           AU
# ...           ...                                   ...          ...
# 2187          NaN                                   NaN          NaN
# 2188          NaN                                   NaN          NaN
# 2189          NaN                                   NaN          NaN
# 2190          NaN                                   NaN          NaN
# 2191          NaN                                   NaN          NaN
#
#       country_text                                  name country_iso2  \
# 0               UK              4H Jena Engineering GmbH           DE
# 1               UK       AB Connectors (Northampton) Ltd           GB
# 2               UK              AB Precision (Poole) Ltd           GB
# 3     Rep. Ireland  ABRO (Army Base Repair Organisation)           GB
# 4        Australia              ABSL Power Solutions Ltd           GB
# ...            ...                                   ...          ...
# 2187           NaN                                   NaN          NaN
# 2188           NaN                                   NaN          NaN
# 2189           NaN                                   NaN          NaN
# 2190           NaN                                   NaN          NaN
# 2191           NaN                                   NaN          NaN
#
#      country_text                                  name
# 0         Germany                          A1 Solutions
# 1              UK               Aardvark Clear Mine Ltd
# 2              UK                   Aarhus Flydedok A/S
# 3              UK                  AB Precision (Poole)
# 4              UK  ABRO - Army Base Repair Organisation
# ...           ...                                   ...
# 2187          NaN                                   NaN
# 2188          NaN                                   NaN
# 2189          NaN                                   NaN
# 2190          NaN                                   NaN
# 2191          NaN                                   NaN
#
# [2192 rows x 38 columns]
